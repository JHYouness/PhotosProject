# %% [markdown]
# ## Modelo de predicción de edad

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("frabbisw/facial-age")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/facial-age

# %%
import os
import shutil

source_dir = '/kaggle/input/facial-age/face_age'
target_dir = '/kaggle/working/face_age_cleaned'

os.makedirs(target_dir, exist_ok=True)

for item in os.listdir(source_dir):
    src_path = os.path.join(source_dir, item)
    dst_path = os.path.join(target_dir, item)

    # Omitimos la carpeta duplicada
    if item == 'face_age':
        continue

    if os.path.isdir(src_path):
        shutil.copytree(src_path, dst_path)
    else:
        shutil.copy2(src_path, dst_path)

print("Contenido copiado a /kaggle/working/face_age_cleaned sin la carpeta problemática.")
# Out:
# Contenido copiado a /kaggle/working/face_age_cleaned sin la carpeta problemática.

# %%
# normalizar_imagenes.py
import os
import shutil

source_dir = '/kaggle/working/face_age_cleaned'
target_dir = '/kaggle/working/face_age_cleaned_binary'

# Crear carpetas destino
os.makedirs(os.path.join(target_dir, '0'), exist_ok=True)  # Menores de edad
os.makedirs(os.path.join(target_dir, '1'), exist_ok=True)  # Mayores de edad

for folder_name in os.listdir(source_dir):
    folder_path = os.path.join(source_dir, folder_name)

    if not os.path.isdir(folder_path):
        continue

    try:
        edad = int(folder_name)  # Ej: '024' → 24
    except ValueError:
        continue

    clase = '0' if edad < 18 else '1'
    destino_clase = os.path.join(target_dir, clase)

    for filename in os.listdir(folder_path):
        src_path = os.path.join(folder_path, filename)

        if os.path.isfile(src_path):
            dst_path = os.path.join(destino_clase, f"{folder_name}_{filename}")
            shutil.copy2(src_path, dst_path)

print("✔️ Imágenes clasificadas por edad en face_age_cleaned_binary/")
# Out:
# ✔️ Imágenes clasificadas por edad en face_age_cleaned_binary/

# %%
# 1. Librerías
import kagglehub
import os
import shutil
import random
from pathlib import Path
import tensorflow as tf
from tensorflow.keras import layers, models, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 6. Modelo CNN
input_shape = (224, 224, 3)
batch_size = 32
epochs = 20
DATA_DIR = "/kaggle/working/face_age_cleaned_binary"


# Generador de datos
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    DATA_DIR,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    DATA_DIR,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)

def crear_modelo_cnn(input_shape):
    model = models.Sequential()

    # Bloque 1
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Bloque 2
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Bloque 3
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    """# Bloque 4 (opcional)
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.25))"""

    # Clasificación
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, activation='sigmoid'))  # salida binaria

    return model

"""
input_layer = layers.Input(shape=input_shape)

layer_conv = layers.Conv2D(32, (3,3), padding='same', activation='relu')(input_layer)
batch_normalization = layers.BatchNormalization()(layer_conv)
pool = layers.MaxPooling2D((2, 2))(batch_normalization)

layer_conv = layers.Conv2D(64, (3,3), padding='same', activation='relu')(pool)
batch_normalization = layers.BatchNormalization()(layer_conv)
pool = layers.MaxPooling2D((2, 2))(batch_normalization)

layer_conv = layers.Conv2D(128, (3,3), padding='same', activation='relu')(pool)
batch_normalization = layers.BatchNormalization()(layer_conv)
pool = layers.MaxPooling2D((2, 2))(batch_normalization)

flatten = layers.Flatten()(pool)
dense = layers.Dense(250, activation='relu')(flatten)
dropout = layers.Dropout(0.5)(dense)
output = layers.Dense(1, activation='sigmoid')(dropout)

model = Model(inputs=input_layer, outputs=output)
"""

model = crear_modelo_cnn(input_shape)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.AUC(name="AUC"),
                       tf.keras.metrics.Precision(name="precision"),
                       tf.keras.metrics.Recall(name="recall")])

model.summary()

# 8. Entrenar

checkpoint = ModelCheckpoint(
    filepath='mejor_modelo3.keras',
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

#early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(train_generator,
                    validation_data=val_generator,
                    epochs=20,
                    callbacks=[checkpoint])
# Out:
# Found 7823 images belonging to 2 classes.
# Found 1955 images belonging to 2 classes.
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)              │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │    12,845,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,939,457 (49.36 MB)
#  Trainable params: 12,939,009 (49.36 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - AUC: 0.7301 - accuracy: 0.7003 - loss: 3.8169 - precision: 0.7146 - recall: 0.8159
# Epoch 1: val_loss improved from inf to 0.99045, saving model to mejor_modelo3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 43s 151ms/step - AUC: 0.7303 - accuracy: 0.7005 - loss: 3.8073 - precision: 0.7147 - recall: 0.8162 - val_AUC: 0.9320 - val_accuracy: 0.8363 - val_loss: 0.9905 - val_precision: 0.9570 - val_recall: 0.7607
# Epoch 2/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.8824 - accuracy: 0.7991 - loss: 0.4461 - precision: 0.7715 - recall: 0.9376
# Epoch 2: val_loss improved from 0.99045 to 0.67123, saving model to mejor_modelo3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 29s 117ms/step - AUC: 0.8824 - accuracy: 0.7992 - loss: 0.4460 - precision: 0.7716 - recall: 0.9376 - val_AUC: 0.9591 - val_accuracy: 0.7304 - val_loss: 0.6712 - val_precision: 0.9707 - val_recall: 0.5667
# Epoch 3/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - AUC: 0.9437 - accuracy: 0.8691 - loss: 0.2963 - precision: 0.8496 - recall: 0.9477
# Epoch 3: val_loss improved from 0.67123 to 0.31444, saving model to mejor_modelo3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 41s 116ms/step - AUC: 0.9437 - accuracy: 0.8691 - loss: 0.2963 - precision: 0.8496 - recall: 0.9477 - val_AUC: 0.9751 - val_accuracy: 0.8967 - val_loss: 0.3144 - val_precision: 0.9727 - val_recall: 0.8513
# Epoch 4/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9576 - accuracy: 0.8898 - loss: 0.2523 - precision: 0.8673 - recall: 0.9674
# Epoch 4: val_loss did not improve from 0.31444
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 112ms/step - AUC: 0.9576 - accuracy: 0.8898 - loss: 0.2523 - precision: 0.8673 - recall: 0.9674 - val_AUC: 0.8934 - val_accuracy: 0.7836 - val_loss: 0.5908 - val_precision: 0.8927 - val_recall: 0.7256
# Epoch 5/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9577 - accuracy: 0.8884 - loss: 0.2407 - precision: 0.8603 - recall: 0.9713
# Epoch 5: val_loss did not improve from 0.31444
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 112ms/step - AUC: 0.9577 - accuracy: 0.8884 - loss: 0.2406 - precision: 0.8603 - recall: 0.9713 - val_AUC: 0.9732 - val_accuracy: 0.8471 - val_loss: 0.4154 - val_precision: 0.9760 - val_recall: 0.7632
# Epoch 6/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9675 - accuracy: 0.9103 - loss: 0.2119 - precision: 0.8882 - recall: 0.9734
# Epoch 6: val_loss did not improve from 0.31444
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 115ms/step - AUC: 0.9675 - accuracy: 0.9103 - loss: 0.2119 - precision: 0.8882 - recall: 0.9734 - val_AUC: 0.9701 - val_accuracy: 0.7703 - val_loss: 0.6274 - val_precision: 0.9839 - val_recall: 0.6265
# Epoch 7/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - AUC: 0.9688 - accuracy: 0.9042 - loss: 0.2097 - precision: 0.8835 - recall: 0.9677
# Epoch 7: val_loss did not improve from 0.31444
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - AUC: 0.9688 - accuracy: 0.9042 - loss: 0.2097 - precision: 0.8835 - recall: 0.9677 - val_AUC: 0.9772 - val_accuracy: 0.9059 - val_loss: 0.3880 - val_precision: 0.9750 - val_recall: 0.8650
# Epoch 8/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9725 - accuracy: 0.9072 - loss: 0.2092 - precision: 0.8797 - recall: 0.9780
# Epoch 8: val_loss did not improve from 0.31444
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 111ms/step - AUC: 0.9725 - accuracy: 0.9072 - loss: 0.2092 - precision: 0.8798 - recall: 0.9780 - val_AUC: 0.9764 - val_accuracy: 0.8020 - val_loss: 0.5068 - val_precision: 0.9863 - val_recall: 0.6786
# Epoch 9/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9744 - accuracy: 0.9103 - loss: 0.2118 - precision: 0.8895 - recall: 0.9720
# Epoch 9: val_loss did not improve from 0.31444
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 111ms/step - AUC: 0.9744 - accuracy: 0.9103 - loss: 0.2118 - precision: 0.8895 - recall: 0.9720 - val_AUC: 0.9772 - val_accuracy: 0.9064 - val_loss: 0.3260 - val_precision: 0.9833 - val_recall: 0.8581
# Epoch 10/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9810 - accuracy: 0.9184 - loss: 0.1624 - precision: 0.8915 - recall: 0.9828
# Epoch 10: val_loss did not improve from 0.31444
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - AUC: 0.9810 - accuracy: 0.9185 - loss: 0.1624 - precision: 0.8916 - recall: 0.9828 - val_AUC: 0.9747 - val_accuracy: 0.8808 - val_loss: 0.4043 - val_precision: 0.9825 - val_recall: 0.8154
# Epoch 11/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - AUC: 0.9831 - accuracy: 0.9351 - loss: 0.1596 - precision: 0.9162 - recall: 0.9812
# Epoch 11: val_loss improved from 0.31444 to 0.21516, saving model to mejor_modelo3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 42s 117ms/step - AUC: 0.9831 - accuracy: 0.9350 - loss: 0.1598 - precision: 0.9161 - recall: 0.9812 - val_AUC: 0.9685 - val_accuracy: 0.9315 - val_loss: 0.2152 - val_precision: 0.9324 - val_recall: 0.9547
# Epoch 12/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9831 - accuracy: 0.9235 - loss: 0.1536 - precision: 0.9027 - recall: 0.9780
# Epoch 12: val_loss did not improve from 0.21516
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - AUC: 0.9831 - accuracy: 0.9235 - loss: 0.1536 - precision: 0.9028 - recall: 0.9780 - val_AUC: 0.9745 - val_accuracy: 0.8788 - val_loss: 0.4124 - val_precision: 0.9824 - val_recall: 0.8120
# Epoch 13/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9774 - accuracy: 0.9190 - loss: 0.2199 - precision: 0.8987 - recall: 0.9715
# Epoch 13: val_loss did not improve from 0.21516
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 111ms/step - AUC: 0.9774 - accuracy: 0.9191 - loss: 0.2198 - precision: 0.8988 - recall: 0.9715 - val_AUC: 0.9723 - val_accuracy: 0.8414 - val_loss: 0.4708 - val_precision: 0.9767 - val_recall: 0.7530
# Epoch 14/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - AUC: 0.9857 - accuracy: 0.9323 - loss: 0.1378 - precision: 0.9112 - recall: 0.9839
# Epoch 14: val_loss did not improve from 0.21516
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 116ms/step - AUC: 0.9857 - accuracy: 0.9323 - loss: 0.1378 - precision: 0.9111 - recall: 0.9839 - val_AUC: 0.9672 - val_accuracy: 0.8798 - val_loss: 0.4788 - val_precision: 0.9805 - val_recall: 0.8154
# Epoch 15/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - AUC: 0.9891 - accuracy: 0.9389 - loss: 0.1220 - precision: 0.9178 - recall: 0.9853
# Epoch 15: val_loss did not improve from 0.21516
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - AUC: 0.9891 - accuracy: 0.9389 - loss: 0.1220 - precision: 0.9178 - recall: 0.9853 - val_AUC: 0.9563 - val_accuracy: 0.7882 - val_loss: 0.7641 - val_precision: 0.9909 - val_recall: 0.6521
# Epoch 16/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - AUC: 0.9904 - accuracy: 0.9475 - loss: 0.1130 - precision: 0.9330 - recall: 0.9839
# Epoch 16: val_loss did not improve from 0.21516
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - AUC: 0.9904 - accuracy: 0.9475 - loss: 0.1130 - precision: 0.9330 - recall: 0.9839 - val_AUC: 0.9542 - val_accuracy: 0.8486 - val_loss: 0.7475 - val_precision: 0.9834 - val_recall: 0.7598
# Epoch 17/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9889 - accuracy: 0.9517 - loss: 0.1218 - precision: 0.9355 - recall: 0.9864
# Epoch 17: val_loss did not improve from 0.21516
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - AUC: 0.9889 - accuracy: 0.9516 - loss: 0.1218 - precision: 0.9355 - recall: 0.9864 - val_AUC: 0.9565 - val_accuracy: 0.8512 - val_loss: 0.6341 - val_precision: 0.9824 - val_recall: 0.7650
# Epoch 18/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9916 - accuracy: 0.9496 - loss: 0.1062 - precision: 0.9318 - recall: 0.9880
# Epoch 18: val_loss did not improve from 0.21516
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 33s 135ms/step - AUC: 0.9916 - accuracy: 0.9496 - loss: 0.1062 - precision: 0.9318 - recall: 0.9880 - val_AUC: 0.9312 - val_accuracy: 0.7857 - val_loss: 1.0706 - val_precision: 0.9858 - val_recall: 0.6513
# Epoch 19/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9914 - accuracy: 0.9490 - loss: 0.1087 - precision: 0.9321 - recall: 0.9880
# Epoch 19: val_loss did not improve from 0.21516
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 112ms/step - AUC: 0.9914 - accuracy: 0.9490 - loss: 0.1088 - precision: 0.9321 - recall: 0.9879 - val_AUC: 0.7915 - val_accuracy: 0.7632 - val_loss: 2.5705 - val_precision: 0.7934 - val_recall: 0.8171
# Epoch 20/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9910 - accuracy: 0.9480 - loss: 0.1105 - precision: 0.9311 - recall: 0.9864
# Epoch 20: val_loss did not improve from 0.21516
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 111ms/step - AUC: 0.9910 - accuracy: 0.9480 - loss: 0.1105 - precision: 0.9312 - recall: 0.9864 - val_AUC: 0.9672 - val_accuracy: 0.8849 - val_loss: 0.6001 - val_precision: 0.9886 - val_recall: 0.8171

# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import numpy as np
import seaborn as sns
import pandas as pd

# Configuración
BATCH_SIZE = 32
DATA_DIR = "/kaggle/working/face_age_cleaned_binary"

# Generador de datos sin mezcla, para evaluación
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

val_gen = datagen.flow_from_directory(
    DATA_DIR,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation',
    shuffle=False  # Importante para que coincidan los índices con las predicciones
)

# Cargar modelo entrenado
model = tf.keras.models.load_model("/content/mejor_modelo3.keras")

# Predicciones
predictions = model.predict(val_gen)
predicted_classes = (predictions > 0.5).astype(int).flatten()
true_classes = val_gen.classes
class_labels = list(val_gen.class_indices.keys())

# Matriz de confusión
cm = confusion_matrix(true_classes, predicted_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)

# Clasificación detallada
report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
df_report = pd.DataFrame(report).transpose()

# Graficar
fig, axs = plt.subplots(1, 2, figsize=(15, 6))

# Matriz de confusión
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels, ax=axs[0])
axs[0].set_title("Matriz de Confusión")
axs[0].set_xlabel("Predicción")
axs[0].set_ylabel("Real")

# Gráfico de métricas por clase
df_report.loc[['0', '1'], ['precision', 'recall', 'f1-score']].plot(kind='bar', ax=axs[1])
axs[1].set_title("Precisión, Recall y F1-score por clase")
axs[1].set_xticklabels(['Menor de edad (0)', 'Mayor de edad (1)'], rotation=0)
axs[1].legend(loc='lower right')

plt.tight_layout()
plt.show()
# Out:
# Found 1955 images belonging to 2 classes.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step

# %%
import matplotlib.pyplot as plt

# Extraer métricas
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
precision = history.history['precision']
val_precision = history.history['val_precision']
recall = history.history['recall']
val_recall = history.history['val_recall']
epochs_range = range(epochs)

# Crear gráficas
plt.figure(figsize=(18, 5))

# Precisión (Precision)
plt.subplot(1, 3, 1)
plt.plot(epochs_range, precision, label='Entrenamiento')
plt.plot(epochs_range, val_precision, label='Validación')
plt.legend(loc='lower right')
plt.title('Precisión (Precision)')

# Sensibilidad (Recall)
plt.subplot(1, 3, 2)
plt.plot(epochs_range, recall, label='Entrenamiento')
plt.plot(epochs_range, val_recall, label='Validación')
plt.legend(loc='lower right')
plt.title('Sensibilidad (Recall)')

# Pérdida (Loss)
plt.subplot(1, 3, 3)
plt.plot(epochs_range, loss, label='Entrenamiento')
plt.plot(epochs_range, val_loss, label='Validación')
plt.legend(loc='upper right')
plt.title('Pérdida (Loss)')

plt.tight_layout()
plt.show()

# %%
model.save("modelo_edad.keras")

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Reemplaza por el nombre real de tu imagen subida
img_path = "/content/Captura de pantalla 2025-05-28 212743.png"

# Mostrar la imagen
img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
plt.axis('off')
plt.title("Imagen para predicción")
plt.show()

# Preprocesar imagen
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Añadir batch dimension
img_array = img_array / 255.0  # Normalizar (opcional, si entrenaste así)

# %%
from tensorflow.keras.models import load_model

# Cargar el modelo guardado
model = load_model("/content/mejor_modelo2.keras")

# Ahora puedes hacer predicciones
prediction = model.predict(img_array)

# Mostrar resultado
if prediction[0] >= 0.5:
    print("🧓 Predicción: MAYOR de edad")
else:
    print("🧒 Predicción: MENOR de edad")

print(f"Probabilidad: {float(prediction[0]):.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 🧒 Predicción: MENOR de edad
# Probabilidad: 0.1859
# <ipython-input-59-2b5a15553022>:15: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(f"Probabilidad: {float(prediction[0]):.4f}")
