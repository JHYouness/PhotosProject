# %% [markdown]
# ## Modelo de predicción de edad

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("frabbisw/facial-age")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/facial-age

# %%
import os
import shutil

source_dir = '/kaggle/input/facial-age/face_age'
target_dir = '/kaggle/working/face_age_cleaned'

os.makedirs(target_dir, exist_ok=True)

for item in os.listdir(source_dir):
    src_path = os.path.join(source_dir, item)
    dst_path = os.path.join(target_dir, item)

    # Omitimos la carpeta duplicada
    if item == 'face_age':
        continue

    if os.path.isdir(src_path):
        shutil.copytree(src_path, dst_path)
    else:
        shutil.copy2(src_path, dst_path)

print("Contenido copiado a /kaggle/working/face_age_cleaned sin la carpeta problemática.")
# Out:
# Contenido copiado a /kaggle/working/face_age_cleaned sin la carpeta problemática.

# %%
# normalizar_imagenes.py
import os
import shutil

source_dir = '/kaggle/working/face_age_cleaned'
target_dir = '/kaggle/working/face_age_cleaned_binary'

# Crear carpetas destino
os.makedirs(os.path.join(target_dir, '0'), exist_ok=True)  # Menores de edad
os.makedirs(os.path.join(target_dir, '1'), exist_ok=True)  # Mayores de edad

for folder_name in os.listdir(source_dir):
    folder_path = os.path.join(source_dir, folder_name)

    if not os.path.isdir(folder_path):
        continue

    try:
        edad = int(folder_name)  # Ej: '024' → 24
    except ValueError:
        continue

    clase = '0' if edad < 18 else '1'
    destino_clase = os.path.join(target_dir, clase)

    for filename in os.listdir(folder_path):
        src_path = os.path.join(folder_path, filename)

        if os.path.isfile(src_path):
            dst_path = os.path.join(destino_clase, f"{folder_name}_{filename}")
            shutil.copy2(src_path, dst_path)

print("✔️ Imágenes clasificadas por edad en face_age_cleaned_binary/")
# Out:
# ✔️ Imágenes clasificadas por edad en face_age_cleaned_binary/

# %%
# 1. Librerías
import kagglehub
import os
import shutil
import random
from pathlib import Path
import tensorflow as tf
from tensorflow.keras import layers, models, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 6. Modelo CNN
input_shape = (224, 224, 3)
batch_size = 32
epochs = 20
DATA_DIR = "/kaggle/working/face_age_cleaned_binary"


# Generador de datos
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    DATA_DIR,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    DATA_DIR,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)

def crear_modelo_cnn(input_shape):
    model = models.Sequential()

    # Bloque 1
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Bloque 2
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Bloque 3
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    """# Bloque 4 (opcional)
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.25))"""

    # Clasificación
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, activation='sigmoid'))  # salida binaria

    return model

"""
input_layer = layers.Input(shape=input_shape)

layer_conv = layers.Conv2D(32, (3,3), padding='same', activation='relu')(input_layer)
batch_normalization = layers.BatchNormalization()(layer_conv)
pool = layers.MaxPooling2D((2, 2))(batch_normalization)

layer_conv = layers.Conv2D(64, (3,3), padding='same', activation='relu')(pool)
batch_normalization = layers.BatchNormalization()(layer_conv)
pool = layers.MaxPooling2D((2, 2))(batch_normalization)

layer_conv = layers.Conv2D(128, (3,3), padding='same', activation='relu')(pool)
batch_normalization = layers.BatchNormalization()(layer_conv)
pool = layers.MaxPooling2D((2, 2))(batch_normalization)

flatten = layers.Flatten()(pool)
dense = layers.Dense(250, activation='relu')(flatten)
dropout = layers.Dropout(0.5)(dense)
output = layers.Dense(1, activation='sigmoid')(dropout)

model = Model(inputs=input_layer, outputs=output)
"""

model = crear_modelo_cnn(input_shape)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.AUC(name="AUC"),
                       tf.keras.metrics.Precision(name="precision"),
                       tf.keras.metrics.Recall(name="recall")])

model.summary()

# 8. Entrenar

checkpoint = ModelCheckpoint(
    filepath='mejor_modelo2.keras',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)

#early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(train_generator,
                    validation_data=val_generator,
                    epochs=20,
                    callbacks=[checkpoint])
# Out:
# Found 7823 images belonging to 2 classes.
# Found 1955 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │    12,845,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,939,457 (49.36 MB)
#  Trainable params: 12,939,009 (49.36 MB)
#  Non-trainable params: 448 (1.75 KB)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - AUC: 0.7534 - accuracy: 0.7179 - loss: 2.5505 - precision: 0.7293 - recall: 0.8384
# Epoch 1: val_accuracy improved from -inf to 0.52839, saving model to mejor_modelo2.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 40s 138ms/step - AUC: 0.7537 - accuracy: 0.7181 - loss: 2.5440 - precision: 0.7294 - recall: 0.8387 - val_AUC: 0.6245 - val_accuracy: 0.5284 - val_loss: 10.5941 - val_precision: 0.8316 - val_recall: 0.2658
# Epoch 2/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - AUC: 0.9237 - accuracy: 0.8191 - loss: 0.3472 - precision: 0.8062 - recall: 0.9213
# Epoch 2: val_accuracy improved from 0.52839 to 0.75754, saving model to mejor_modelo2.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 29s 118ms/step - AUC: 0.9237 - accuracy: 0.8191 - loss: 0.3471 - precision: 0.8064 - recall: 0.9211 - val_AUC: 0.9337 - val_accuracy: 0.7575 - val_loss: 0.7636 - val_precision: 0.9485 - val_recall: 0.6291
# Epoch 3/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - AUC: 0.9547 - accuracy: 0.8781 - loss: 0.2661 - precision: 0.8806 - recall: 0.9255
# Epoch 3: val_accuracy did not improve from 0.75754
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 115ms/step - AUC: 0.9547 - accuracy: 0.8782 - loss: 0.2661 - precision: 0.8807 - recall: 0.9255 - val_AUC: 0.9684 - val_accuracy: 0.7248 - val_loss: 0.6963 - val_precision: 0.9832 - val_recall: 0.5496
# Epoch 4/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9608 - accuracy: 0.9041 - loss: 0.2679 - precision: 0.9210 - recall: 0.9178
# Epoch 4: val_accuracy improved from 0.75754 to 0.93299, saving model to mejor_modelo2.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 29s 118ms/step - AUC: 0.9608 - accuracy: 0.9041 - loss: 0.2678 - precision: 0.9210 - recall: 0.9178 - val_AUC: 0.9760 - val_accuracy: 0.9330 - val_loss: 0.2160 - val_precision: 0.9668 - val_recall: 0.9197
# Epoch 5/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - AUC: 0.9695 - accuracy: 0.9089 - loss: 0.2161 - precision: 0.9318 - recall: 0.9144
# Epoch 5: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 110ms/step - AUC: 0.9695 - accuracy: 0.9089 - loss: 0.2161 - precision: 0.9318 - recall: 0.9144 - val_AUC: 0.9842 - val_accuracy: 0.8905 - val_loss: 0.2763 - val_precision: 0.9848 - val_recall: 0.8299
# Epoch 6/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9797 - accuracy: 0.9255 - loss: 0.1824 - precision: 0.9481 - recall: 0.9226
# Epoch 6: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 111ms/step - AUC: 0.9797 - accuracy: 0.9255 - loss: 0.1824 - precision: 0.9481 - recall: 0.9226 - val_AUC: 0.9378 - val_accuracy: 0.5775 - val_loss: 1.3791 - val_precision: 0.9725 - val_recall: 0.3026
# Epoch 7/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9836 - accuracy: 0.9311 - loss: 0.1541 - precision: 0.9599 - recall: 0.9240
# Epoch 7: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 111ms/step - AUC: 0.9836 - accuracy: 0.9311 - loss: 0.1541 - precision: 0.9599 - recall: 0.9240 - val_AUC: 0.9754 - val_accuracy: 0.7647 - val_loss: 0.4629 - val_precision: 0.9850 - val_recall: 0.6162
# Epoch 8/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - AUC: 0.9841 - accuracy: 0.9330 - loss: 0.1548 - precision: 0.9622 - recall: 0.9244
# Epoch 8: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 116ms/step - AUC: 0.9841 - accuracy: 0.9330 - loss: 0.1548 - precision: 0.9622 - recall: 0.9244 - val_AUC: 0.9402 - val_accuracy: 0.8624 - val_loss: 0.3895 - val_precision: 0.9129 - val_recall: 0.8513
# Epoch 9/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - AUC: 0.9815 - accuracy: 0.9221 - loss: 0.1682 - precision: 0.9620 - recall: 0.9055
# Epoch 9: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 111ms/step - AUC: 0.9815 - accuracy: 0.9221 - loss: 0.1682 - precision: 0.9620 - recall: 0.9055 - val_AUC: 0.9652 - val_accuracy: 0.6946 - val_loss: 0.7051 - val_precision: 0.9848 - val_recall: 0.4974
# Epoch 10/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9861 - accuracy: 0.9379 - loss: 0.1460 - precision: 0.9642 - recall: 0.9307
# Epoch 10: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 111ms/step - AUC: 0.9861 - accuracy: 0.9379 - loss: 0.1460 - precision: 0.9642 - recall: 0.9306 - val_AUC: 0.9650 - val_accuracy: 0.8506 - val_loss: 0.4090 - val_precision: 0.9690 - val_recall: 0.7752
# Epoch 11/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9854 - accuracy: 0.9338 - loss: 0.1424 - precision: 0.9706 - recall: 0.9187
# Epoch 11: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 110ms/step - AUC: 0.9854 - accuracy: 0.9338 - loss: 0.1424 - precision: 0.9706 - recall: 0.9188 - val_AUC: 0.9704 - val_accuracy: 0.8384 - val_loss: 0.3783 - val_precision: 0.9713 - val_recall: 0.7521
# Epoch 12/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9913 - accuracy: 0.9461 - loss: 0.1139 - precision: 0.9792 - recall: 0.9308
# Epoch 12: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - AUC: 0.9913 - accuracy: 0.9461 - loss: 0.1140 - precision: 0.9792 - recall: 0.9308 - val_AUC: 0.9500 - val_accuracy: 0.8251 - val_loss: 0.5093 - val_precision: 0.9770 - val_recall: 0.7248
# Epoch 13/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - AUC: 0.9774 - accuracy: 0.9045 - loss: 0.1834 - precision: 0.9595 - recall: 0.8808
# Epoch 13: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - AUC: 0.9774 - accuracy: 0.9046 - loss: 0.1833 - precision: 0.9595 - recall: 0.8809 - val_AUC: 0.9718 - val_accuracy: 0.7944 - val_loss: 0.5021 - val_precision: 0.9885 - val_recall: 0.6641
# Epoch 14/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - AUC: 0.9874 - accuracy: 0.9355 - loss: 0.1341 - precision: 0.9743 - recall: 0.9159
# Epoch 14: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - AUC: 0.9874 - accuracy: 0.9356 - loss: 0.1341 - precision: 0.9743 - recall: 0.9160 - val_AUC: 0.9636 - val_accuracy: 0.7729 - val_loss: 0.6446 - val_precision: 0.9827 - val_recall: 0.6316
# Epoch 15/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9905 - accuracy: 0.9428 - loss: 0.1150 - precision: 0.9788 - recall: 0.9246
# Epoch 15: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 110ms/step - AUC: 0.9905 - accuracy: 0.9428 - loss: 0.1150 - precision: 0.9788 - recall: 0.9246 - val_AUC: 0.9375 - val_accuracy: 0.7176 - val_loss: 1.0888 - val_precision: 0.9858 - val_recall: 0.5359
# Epoch 16/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9912 - accuracy: 0.9484 - loss: 0.1112 - precision: 0.9789 - recall: 0.9341
# Epoch 16: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - AUC: 0.9912 - accuracy: 0.9484 - loss: 0.1112 - precision: 0.9789 - recall: 0.9341 - val_AUC: 0.9649 - val_accuracy: 0.7591 - val_loss: 0.5797 - val_precision: 0.9847 - val_recall: 0.6068
# Epoch 17/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9906 - accuracy: 0.9514 - loss: 0.1139 - precision: 0.9776 - recall: 0.9391
# Epoch 17: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - AUC: 0.9906 - accuracy: 0.9514 - loss: 0.1139 - precision: 0.9776 - recall: 0.9391 - val_AUC: 0.9531 - val_accuracy: 0.7811 - val_loss: 0.7279 - val_precision: 0.9744 - val_recall: 0.6513
# Epoch 18/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - AUC: 0.9882 - accuracy: 0.9409 - loss: 0.1733 - precision: 0.9715 - recall: 0.9283
# Epoch 18: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 112ms/step - AUC: 0.9882 - accuracy: 0.9409 - loss: 0.1731 - precision: 0.9715 - recall: 0.9283 - val_AUC: 0.9521 - val_accuracy: 0.8046 - val_loss: 0.7997 - val_precision: 0.9876 - val_recall: 0.6821
# Epoch 19/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9938 - accuracy: 0.9537 - loss: 0.0916 - precision: 0.9829 - recall: 0.9400
# Epoch 19: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 111ms/step - AUC: 0.9938 - accuracy: 0.9537 - loss: 0.0916 - precision: 0.9829 - recall: 0.9400 - val_AUC: 0.9496 - val_accuracy: 0.8082 - val_loss: 0.8144 - val_precision: 0.9818 - val_recall: 0.6923
# Epoch 20/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - AUC: 0.9960 - accuracy: 0.9678 - loss: 0.0700 - precision: 0.9890 - recall: 0.9568
# Epoch 20: val_accuracy did not improve from 0.93299
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - AUC: 0.9960 - accuracy: 0.9678 - loss: 0.0700 - precision: 0.9890 - recall: 0.9568 - val_AUC: 0.9296 - val_accuracy: 0.7652 - val_loss: 1.1097 - val_precision: 0.9877 - val_recall: 0.6154

# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import numpy as np
import seaborn as sns
import pandas as pd

# Configuración
BATCH_SIZE = 32
DATA_DIR = "/kaggle/working/face_age_cleaned_binary"

# Generador de datos sin mezcla, para evaluación
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

val_gen = datagen.flow_from_directory(
    DATA_DIR,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation',
    shuffle=False  # Importante para que coincidan los índices con las predicciones
)

# Cargar modelo entrenado
model = tf.keras.models.load_model("/content/mejor_modelo2.keras")

# Predicciones
predictions = model.predict(val_gen)
predicted_classes = (predictions > 0.5).astype(int).flatten()
true_classes = val_gen.classes
class_labels = list(val_gen.class_indices.keys())

# Matriz de confusión
cm = confusion_matrix(true_classes, predicted_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)

# Clasificación detallada
report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
df_report = pd.DataFrame(report).transpose()

# Graficar
fig, axs = plt.subplots(1, 2, figsize=(15, 6))

# Matriz de confusión
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels, ax=axs[0])
axs[0].set_title("Matriz de Confusión")
axs[0].set_xlabel("Predicción")
axs[0].set_ylabel("Real")

# Gráfico de métricas por clase
df_report.loc[['0', '1'], ['precision', 'recall', 'f1-score']].plot(kind='bar', ax=axs[1])
axs[1].set_title("Precisión, Recall y F1-score por clase")
axs[1].set_xticklabels(['Menor de edad (0)', 'Mayor de edad (1)'], rotation=0)
axs[1].legend(loc='lower right')

plt.tight_layout()
plt.show()
# Out:
# Found 1955 images belonging to 2 classes.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step

# %%
import matplotlib.pyplot as plt

# Extraer métricas
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
precision = history.history['precision']
val_precision = history.history['val_precision']
recall = history.history['recall']
val_recall = history.history['val_recall']
epochs_range = range(len(acc))

# Crear gráficas
plt.figure(figsize=(18, 5))

# Precisión (Precision)
plt.subplot(1, 3, 1)
plt.plot(epochs_range, precision, label='Entrenamiento')
plt.plot(epochs_range, val_precision, label='Validación')
plt.legend(loc='lower right')
plt.title('Precisión (Precision)')

# Sensibilidad (Recall)
plt.subplot(1, 3, 2)
plt.plot(epochs_range, recall, label='Entrenamiento')
plt.plot(epochs_range, val_recall, label='Validación')
plt.legend(loc='lower right')
plt.title('Sensibilidad (Recall)')

# Pérdida (Loss)
plt.subplot(1, 3, 3)
plt.plot(epochs_range, loss, label='Entrenamiento')
plt.plot(epochs_range, val_loss, label='Validación')
plt.legend(loc='upper right')
plt.title('Pérdida (Loss)')

plt.tight_layout()
plt.show()

# %%
model.save("modelo_edad.keras")

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Reemplaza por el nombre real de tu imagen subida
img_path = "/content/Captura de pantalla 2025-05-28 212326.png"

# Mostrar la imagen
img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
plt.axis('off')
plt.title("Imagen para predicción")
plt.show()

# Preprocesar imagen
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Añadir batch dimension
img_array = img_array / 255.0  # Normalizar (opcional, si entrenaste así)

# %%
from tensorflow.keras.models import load_model

# Cargar el modelo guardado
model = load_model("/content/mejor_modelo2.keras")

# Ahora puedes hacer predicciones
prediction = model.predict(img_array)

# Mostrar resultado
if prediction[0] >= 0.5:
    print("🧓 Predicción: MAYOR de edad")
else:
    print("🧒 Predicción: MENOR de edad")

print(f"Probabilidad: {float(prediction[0]):.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 🧓 Predicción: MAYOR de edad
# Probabilidad: 0.7530
# <ipython-input-52-2b5a15553022>:15: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(f"Probabilidad: {float(prediction[0]):.4f}")
