# %% [markdown]
# ## Modelo de predicción de edad

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("frabbisw/facial-age")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/facial-age

# %%
import os
import shutil

source_dir = '/kaggle/input/facial-age/face_age'
target_dir = '/kaggle/working/face_age_cleaned'

os.makedirs(target_dir, exist_ok=True)

for item in os.listdir(source_dir):
    src_path = os.path.join(source_dir, item)
    dst_path = os.path.join(target_dir, item)

    # Omitimos la carpeta duplicada
    if item == 'face_age':
        continue

    if os.path.isdir(src_path):
        shutil.copytree(src_path, dst_path)
    else:
        shutil.copy2(src_path, dst_path)

print("Contenido copiado a /kaggle/working/face_age_cleaned sin la carpeta problemática.")
# Out:
# Contenido copiado a /kaggle/working/face_age_cleaned sin la carpeta problemática.

# %%
# normalizar_imagenes.py
import os
import shutil

source_dir = '/kaggle/working/face_age_cleaned'
target_dir = '/kaggle/working/face_age_cleaned_binary'

# Crear carpetas destino
os.makedirs(os.path.join(target_dir, '0'), exist_ok=True)  # Menores de edad
os.makedirs(os.path.join(target_dir, '1'), exist_ok=True)  # Mayores de edad

for folder_name in os.listdir(source_dir):
    folder_path = os.path.join(source_dir, folder_name)

    if not os.path.isdir(folder_path):
        continue

    try:
        edad = int(folder_name)  # Ej: '024' → 24
    except ValueError:
        continue

    clase = '0' if edad < 18 else '1'
    destino_clase = os.path.join(target_dir, clase)

    for filename in os.listdir(folder_path):
        src_path = os.path.join(folder_path, filename)

        if os.path.isfile(src_path):
            dst_path = os.path.join(destino_clase, f"{folder_name}_{filename}")
            shutil.copy2(src_path, dst_path)

print("✔️ Imágenes clasificadas por edad en face_age_cleaned_binary/")
# Out:
# ✔️ Imágenes clasificadas por edad en face_age_cleaned_binary/

# %%
# 1. Librerías
import kagglehub
import os
import shutil
import random
from pathlib import Path
import tensorflow as tf
from tensorflow.keras import layers, models, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 6. Modelo CNN
input_shape = (224, 224, 3)
batch_size = 32
epochs = 20
DATA_DIR = "/kaggle/working/face_age_cleaned_binary"


# Generador de datos
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    DATA_DIR,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    DATA_DIR,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)

def crear_modelo_cnn(input_shape):
    model = models.Sequential()

    # Bloque 1
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Bloque 2
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Bloque 3
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Bloque 4 (opcional)
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.25))

    # Clasificación
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, activation='sigmoid'))  # salida binaria

    return model

"""
input_layer = layers.Input(shape=input_shape)

layer_conv = layers.Conv2D(32, (3,3), padding='same', activation='relu')(input_layer)
batch_normalization = layers.BatchNormalization()(layer_conv)
pool = layers.MaxPooling2D((2, 2))(batch_normalization)

layer_conv = layers.Conv2D(64, (3,3), padding='same', activation='relu')(pool)
batch_normalization = layers.BatchNormalization()(layer_conv)
pool = layers.MaxPooling2D((2, 2))(batch_normalization)

layer_conv = layers.Conv2D(128, (3,3), padding='same', activation='relu')(pool)
batch_normalization = layers.BatchNormalization()(layer_conv)
pool = layers.MaxPooling2D((2, 2))(batch_normalization)

flatten = layers.Flatten()(pool)
dense = layers.Dense(250, activation='relu')(flatten)
dropout = layers.Dropout(0.5)(dense)
output = layers.Dense(1, activation='sigmoid')(dropout)

model = Model(inputs=input_layer, outputs=output)
"""

model = crear_modelo_cnn(input_shape)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.AUC(name="AUC"),
                       tf.keras.metrics.Precision(name="precision"),
                       tf.keras.metrics.Recall(name="recall")])

model.summary()

# 8. Entrenar

checkpoint = ModelCheckpoint(
    filepath='mejor_modelo1.keras',
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

#early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(train_generator,
                    validation_data=val_generator,
                    epochs=20,
                    callbacks=[checkpoint])
# Out:
# Found 7823 images belonging to 2 classes.
# Found 1955 images belonging to 2 classes.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │     6,422,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,813,121 (25.99 MB)
#  Trainable params: 6,812,161 (25.99 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - AUC: 0.7377 - accuracy: 0.6992 - loss: 1.8731 - precision: 0.7151 - recall: 0.8083
# Epoch 1: val_loss improved from inf to 0.78949, saving model to mejor_modelo1.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 42s 138ms/step - AUC: 0.7380 - accuracy: 0.6994 - loss: 1.8691 - precision: 0.7152 - recall: 0.8086 - val_AUC: 0.9216 - val_accuracy: 0.8471 - val_loss: 0.7895 - val_precision: 0.9342 - val_recall: 0.8009
# Epoch 2/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9251 - accuracy: 0.8505 - loss: 0.3409 - precision: 0.8363 - recall: 0.9325
# Epoch 2: val_loss improved from 0.78949 to 0.55047, saving model to mejor_modelo1.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - AUC: 0.9252 - accuracy: 0.8506 - loss: 0.3408 - precision: 0.8363 - recall: 0.9325 - val_AUC: 0.8803 - val_accuracy: 0.8409 - val_loss: 0.5505 - val_precision: 0.8450 - val_recall: 0.8991
# Epoch 3/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9596 - accuracy: 0.9003 - loss: 0.2634 - precision: 0.8898 - recall: 0.9491
# Epoch 3: val_loss improved from 0.55047 to 0.32396, saving model to mejor_modelo1.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 115ms/step - AUC: 0.9596 - accuracy: 0.9003 - loss: 0.2633 - precision: 0.8898 - recall: 0.9491 - val_AUC: 0.9762 - val_accuracy: 0.8849 - val_loss: 0.3240 - val_precision: 0.9749 - val_recall: 0.8291
# Epoch 4/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - AUC: 0.9726 - accuracy: 0.9169 - loss: 0.2063 - precision: 0.9056 - recall: 0.9609
# Epoch 4: val_loss improved from 0.32396 to 0.31917, saving model to mejor_modelo1.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - AUC: 0.9726 - accuracy: 0.9169 - loss: 0.2063 - precision: 0.9056 - recall: 0.9609 - val_AUC: 0.9749 - val_accuracy: 0.8946 - val_loss: 0.3192 - val_precision: 0.9763 - val_recall: 0.8444
# Epoch 5/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9808 - accuracy: 0.9309 - loss: 0.1715 - precision: 0.9152 - recall: 0.9732
# Epoch 5: val_loss did not improve from 0.31917
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 27s 112ms/step - AUC: 0.9808 - accuracy: 0.9309 - loss: 0.1716 - precision: 0.9152 - recall: 0.9732 - val_AUC: 0.9709 - val_accuracy: 0.8292 - val_loss: 0.4997 - val_precision: 0.9805 - val_recall: 0.7291
# Epoch 6/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - AUC: 0.9828 - accuracy: 0.9392 - loss: 0.1612 - precision: 0.9346 - recall: 0.9659
# Epoch 6: val_loss did not improve from 0.31917
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 42s 116ms/step - AUC: 0.9828 - accuracy: 0.9392 - loss: 0.1612 - precision: 0.9346 - recall: 0.9659 - val_AUC: 0.9733 - val_accuracy: 0.6972 - val_loss: 0.7133 - val_precision: 0.9849 - val_recall: 0.5017
# Epoch 7/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - AUC: 0.9847 - accuracy: 0.9340 - loss: 0.1531 - precision: 0.9253 - recall: 0.9675
# Epoch 7: val_loss improved from 0.31917 to 0.29261, saving model to mejor_modelo1.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 41s 116ms/step - AUC: 0.9847 - accuracy: 0.9340 - loss: 0.1531 - precision: 0.9253 - recall: 0.9675 - val_AUC: 0.9819 - val_accuracy: 0.8941 - val_loss: 0.2926 - val_precision: 0.9820 - val_recall: 0.8385
# Epoch 8/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - AUC: 0.9857 - accuracy: 0.9370 - loss: 0.1474 - precision: 0.9421 - recall: 0.9528
# Epoch 8: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 40s 113ms/step - AUC: 0.9857 - accuracy: 0.9370 - loss: 0.1474 - precision: 0.9421 - recall: 0.9529 - val_AUC: 0.9474 - val_accuracy: 0.8634 - val_loss: 0.3720 - val_precision: 0.9448 - val_recall: 0.8197
# Epoch 9/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9862 - accuracy: 0.9386 - loss: 0.1447 - precision: 0.9266 - recall: 0.9721
# Epoch 9: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - AUC: 0.9862 - accuracy: 0.9386 - loss: 0.1447 - precision: 0.9266 - recall: 0.9721 - val_AUC: 0.9680 - val_accuracy: 0.7621 - val_loss: 0.6214 - val_precision: 0.9916 - val_recall: 0.6077
# Epoch 10/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9907 - accuracy: 0.9513 - loss: 0.1183 - precision: 0.9531 - recall: 0.9668
# Epoch 10: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - AUC: 0.9907 - accuracy: 0.9513 - loss: 0.1183 - precision: 0.9531 - recall: 0.9668 - val_AUC: 0.9722 - val_accuracy: 0.8517 - val_loss: 0.4436 - val_precision: 0.9825 - val_recall: 0.7658
# Epoch 11/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - AUC: 0.9938 - accuracy: 0.9623 - loss: 0.0950 - precision: 0.9567 - recall: 0.9815
# Epoch 11: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - AUC: 0.9938 - accuracy: 0.9623 - loss: 0.0950 - precision: 0.9567 - recall: 0.9815 - val_AUC: 0.9672 - val_accuracy: 0.8133 - val_loss: 0.6265 - val_precision: 0.9891 - val_recall: 0.6957
# Epoch 12/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - AUC: 0.9936 - accuracy: 0.9630 - loss: 0.0961 - precision: 0.9717 - recall: 0.9657
# Epoch 12: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - AUC: 0.9936 - accuracy: 0.9630 - loss: 0.0961 - precision: 0.9717 - recall: 0.9657 - val_AUC: 0.9465 - val_accuracy: 0.6905 - val_loss: 1.0540 - val_precision: 0.9896 - val_recall: 0.4880
# Epoch 13/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - AUC: 0.9954 - accuracy: 0.9667 - loss: 0.0789 - precision: 0.9601 - recall: 0.9855
# Epoch 13: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 116ms/step - AUC: 0.9954 - accuracy: 0.9667 - loss: 0.0789 - precision: 0.9601 - recall: 0.9855 - val_AUC: 0.9443 - val_accuracy: 0.7125 - val_loss: 1.0571 - val_precision: 0.9887 - val_recall: 0.5256
# Epoch 14/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9928 - accuracy: 0.9557 - loss: 0.1023 - precision: 0.9549 - recall: 0.9724
# Epoch 14: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 41s 115ms/step - AUC: 0.9928 - accuracy: 0.9557 - loss: 0.1023 - precision: 0.9550 - recall: 0.9724 - val_AUC: 0.9605 - val_accuracy: 0.7749 - val_loss: 0.7607 - val_precision: 0.9880 - val_recall: 0.6316
# Epoch 15/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - AUC: 0.9950 - accuracy: 0.9660 - loss: 0.0854 - precision: 0.9734 - recall: 0.9697
# Epoch 15: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 115ms/step - AUC: 0.9950 - accuracy: 0.9660 - loss: 0.0854 - precision: 0.9734 - recall: 0.9697 - val_AUC: 0.9676 - val_accuracy: 0.8598 - val_loss: 0.5288 - val_precision: 0.9848 - val_recall: 0.7778
# Epoch 16/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - AUC: 0.9966 - accuracy: 0.9704 - loss: 0.0717 - precision: 0.9778 - recall: 0.9718
# Epoch 16: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - AUC: 0.9966 - accuracy: 0.9704 - loss: 0.0716 - precision: 0.9778 - recall: 0.9718 - val_AUC: 0.9340 - val_accuracy: 0.7770 - val_loss: 1.1202 - val_precision: 0.9920 - val_recall: 0.6325
# Epoch 17/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - AUC: 0.9968 - accuracy: 0.9777 - loss: 0.0605 - precision: 0.9830 - recall: 0.9795
# Epoch 17: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 116ms/step - AUC: 0.9968 - accuracy: 0.9777 - loss: 0.0605 - precision: 0.9830 - recall: 0.9795 - val_AUC: 0.9630 - val_accuracy: 0.8338 - val_loss: 0.6323 - val_precision: 0.9896 - val_recall: 0.7299
# Epoch 18/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - AUC: 0.9958 - accuracy: 0.9726 - loss: 0.0777 - precision: 0.9796 - recall: 0.9748
# Epoch 18: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - AUC: 0.9958 - accuracy: 0.9726 - loss: 0.0777 - precision: 0.9795 - recall: 0.9748 - val_AUC: 0.9384 - val_accuracy: 0.6854 - val_loss: 1.1454 - val_precision: 0.9912 - val_recall: 0.4786
# Epoch 19/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - AUC: 0.9958 - accuracy: 0.9714 - loss: 0.0771 - precision: 0.9784 - recall: 0.9734
# Epoch 19: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - AUC: 0.9958 - accuracy: 0.9714 - loss: 0.0771 - precision: 0.9784 - recall: 0.9734 - val_AUC: 0.9525 - val_accuracy: 0.7540 - val_loss: 0.8218 - val_precision: 0.9805 - val_recall: 0.6009
# Epoch 20/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - AUC: 0.9983 - accuracy: 0.9836 - loss: 0.0494 - precision: 0.9885 - recall: 0.9840
# Epoch 20: val_loss did not improve from 0.29261
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - AUC: 0.9983 - accuracy: 0.9836 - loss: 0.0495 - precision: 0.9885 - recall: 0.9840 - val_AUC: 0.9569 - val_accuracy: 0.8087 - val_loss: 0.6926 - val_precision: 0.9818 - val_recall: 0.6932

# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import numpy as np
import seaborn as sns
import pandas as pd

# Configuración
BATCH_SIZE = 32
DATA_DIR = "/kaggle/working/face_age_cleaned_binary"

# Generador de datos sin mezcla, para evaluación
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

val_gen = datagen.flow_from_directory(
    DATA_DIR,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation',
    shuffle=False  # Importante para que coincidan los índices con las predicciones
)

# Cargar modelo entrenado
model = tf.keras.models.load_model("/content/mejor_modelo1.keras")

# Predicciones
predictions = model.predict(val_gen)
predicted_classes = (predictions > 0.5).astype(int).flatten()
true_classes = val_gen.classes
class_labels = list(val_gen.class_indices.keys())

# Matriz de confusión
cm = confusion_matrix(true_classes, predicted_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)

# Clasificación detallada
report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
df_report = pd.DataFrame(report).transpose()

# Graficar
fig, axs = plt.subplots(1, 2, figsize=(15, 6))

# Matriz de confusión
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels, ax=axs[0])
axs[0].set_title("Matriz de Confusión")
axs[0].set_xlabel("Predicción")
axs[0].set_ylabel("Real")

# Gráfico de métricas por clase
df_report.loc[['0', '1'], ['precision', 'recall', 'f1-score']].plot(kind='bar', ax=axs[1])
axs[1].set_title("Precisión, Recall y F1-score por clase")
axs[1].set_xticklabels(['Menor de edad (0)', 'Mayor de edad (1)'], rotation=0)
axs[1].legend(loc='lower right')

plt.tight_layout()
plt.show()
# Out:
# Found 1955 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step

# %%
import matplotlib.pyplot as plt

# Extraer métricas
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
precision = history.history['precision']
val_precision = history.history['val_precision']
recall = history.history['recall']
val_recall = history.history['val_recall']
epochs_range = range(len(acc))

# Crear gráficas
plt.figure(figsize=(18, 5))

# Precisión (Precision)
plt.subplot(1, 3, 1)
plt.plot(epochs_range, precision, label='Entrenamiento')
plt.plot(epochs_range, val_precision, label='Validación')
plt.legend(loc='lower right')
plt.title('Precisión (Precision)')

# Sensibilidad (Recall)
plt.subplot(1, 3, 2)
plt.plot(epochs_range, recall, label='Entrenamiento')
plt.plot(epochs_range, val_recall, label='Validación')
plt.legend(loc='lower right')
plt.title('Sensibilidad (Recall)')

# Pérdida (Loss)
plt.subplot(1, 3, 3)
plt.plot(epochs_range, loss, label='Entrenamiento')
plt.plot(epochs_range, val_loss, label='Validación')
plt.legend(loc='upper right')
plt.title('Pérdida (Loss)')

plt.tight_layout()
plt.show()

# %%
model.save("modelo_edad.keras")

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Reemplaza por el nombre real de tu imagen subida
img_path = "/content/Captura de pantalla 2025-05-28 212653.png"

# Mostrar la imagen
img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
plt.axis('off')
plt.title("Imagen para predicción")
plt.show()

# Preprocesar imagen
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Añadir batch dimension
img_array = img_array / 255.0  # Normalizar (opcional, si entrenaste así)

# %%
from tensorflow.keras.models import load_model

# Cargar el modelo guardado
model = load_model("/content/mejor_modelo1.keras")

# Ahora puedes hacer predicciones
prediction = model.predict(img_array)

# Mostrar resultado
if prediction[0] >= 0.5:
    print("🧓 Predicción: MAYOR de edad")
else:
    print("🧒 Predicción: MENOR de edad")

print(f"Probabilidad: {float(prediction[0]):.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 🧓 Predicción: MAYOR de edad
# Probabilidad: 0.8874
# <ipython-input-37-bdd03809017e>:15: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(f"Probabilidad: {float(prediction[0]):.4f}")
